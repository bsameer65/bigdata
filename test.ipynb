# %%
import pandas as pd
# Out:
# Running cells with 'bigdata (Python 3.8.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p d:\TU Hamburg\Semester 2\Big data\project\bigdata ipykernel --update-deps --force-reinstall'
